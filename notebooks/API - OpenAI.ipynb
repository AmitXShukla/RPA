# %% [markdown]
# # ChatGPT vs BARD | using GPT Prompts, Code, Interpreter
#
# How to use OpenAI ChatGPT API
# - Python
# - using Curl
#
# ChatGPT Prompt
# - Text completion
# - Code completion
#
# Code Interpreter
#
# BARD vs ChatGPT
#
# ---
# ## How to use OpenAI ChatGPT API
# ---
#
# - web based interface
# - Python API
# - CURL
# - build your own plugin | API

# %%
# pip install openai

import os
import openai
openai.organization = "org-wDk1StTh2q8An7BShjzr6zJF"

openai.api_key = os.getenv("OPENAI_API_KEY") # setup windows environment variable
model_engine = "gpt-3.5-turbo"
model_engine = "text-davinci-003"
openai.Model.list()
# Out:
# <OpenAIObject list at 0x258c664fdd0> JSON: {
#   "data": [
#     {
#       "created": 1677532384,
#       "id": "whisper-1",
#       "object": "model",
#       "owned_by": "openai-internal",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1683912666,
#           "group": null,
#           "id": "modelperm-KlsZlfft3Gma8pI6A8rTnyjs",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "whisper-1"
#     },
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
completion = openai.ChatCompletion.create(
  model=model_engine,
  messages=[
    {"role": "user", "content": "rephrase: I also need an environment (high end machine with more storage) which I can use to schedule BOTs in parallel,These BOTs currently run on 1-2 Laptop machines which slows down data extraction. Storage and transmission.Having a high end Snowflake or Oracle like Data Lake environment, will help me expedite data extraction, reconciliation and transmission."}
  ]
)

print(completion.choices[0].message.content)

# %% [markdown]
# ## using curl

# %% [markdown]
# curl https://api.openai.com/v1/completions \
#   -H "Content-Type: application/json" \
#   -H "Authorization: Bearer $OPENAI_API_KEY" \
#   -d '{
#     "model": "text-davinci-003",
#     "prompt": "Say this is a test",
#     "max_tokens": 7,
#     "temperature": 0
#   }'

# %% [markdown]
# ## ChatGPT Prompt

# %% [markdown]
# #### Text completion

# %% [markdown]
# - write an intro paragraph to my technical blog post about Open AI ChatGPT
# - rephrase this text: My name is Anthony Gonzales,
#   I live alone in slum in Mumbai Dharavi.
#   There is one movie based on my life "Slum dog millionaire" won several awards.
# - what awards movie name Slum dog millionaire won
# - summarize this paragraph
# - create a table from this text
# - classify the named entities in this list.
#   An apple, building, melon, tomato, news paper, sky and moon.
# - translate this text into Arabic: welcome to the RPA youtube tutorials.
# - write a paragraph on the topic of crowd funding request in a formal style
# - write a tweet on impact of global warming on sea life
# - write a blog on indo-chinese cuisine
# - write an email to my boss seeking his approval to move forward with Open AI Project.
# - write my resume based on this summary.
# - persona
#     - write a paragraph on the topic of copying propertied
#     IT design and intellectual property in an informal style
#     - write a paragraph on the topic of copying propertied
#     IT design and intellectual property in an formal style
#     - write a paragraph on the topic of copying propertied
#      IT design and intellectual property in an blogger style

# %% [markdown]
# #### Code Completion
#
# - write code
# - write mermaid graph
# - create an ERD diagram
# - write a docstring description for this function
# def add(x, y):
#     return x + y
# - convert this code from Python to Javascript:
# def add(x, y):
#     return x + y
# - convert this JSON object into XML:
# - convert this text into nodes and edges
# - webscrape - get text from HTML

# %% [markdown]
# ## Code Interpreter
# ---
#
# explain this code

# %% [markdown]
# ## BARD vs ChatGPT vs Llama 2

# %% [markdown]
# write and compare code generated by BARD vs ChatGPT
#
# | Topic | ChatGPT | BARD |
# | -------- | -------- | -------- |
# | [Generate and Read QR Code](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Generate%20and%20Read%20QR%20Code.ipynb)   | 10   | 10   |
# | [Generate Image Watermark](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Generate%20Image%20Watermark.ipynb)   | 10   | 10   |
# | [Tic Tac Toe](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Tic%20Tac%20Toe.ipynb)   | 10   | 10   |
# | [Basic Scientific calculator](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Scientific%20calculator.ipynb)   | 10   | 10   |
# | [Count down timer](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Timer%20Count%20down.ipynb)   | 10   | 9   |
# | [Timer](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Timer.ipynb)   | 10   | 10   |
# | [Boxing match timer for 10 rounds 3 mins each with 2 min break](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Timer%20Boxing.ipynb)   | 10   | 10   |
# | [Jump rope counter](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Timer%20Jump%20rope.ipynb)   | 10   | 7   |
# | [Reading a cookie file](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Reading%20a%20cookie%20file.ipynb)   | 10   | 10   |
# | [Create fake test data using ChatGPT](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Create%20fake%20test%20data%20using%20ChatGPT.ipynb)   | 10   | 10   |
# | [Tree Flattening](https://github.com/AmitXShukla/RPA/blob/main/notebooks/Tree%20Flattening.ipynb)   | 5   | 5   |

# %% [markdown]
# ## how to setup Llama 2
# ---
#
# Before you start, you must sign up with Meta AI to receive an email URL which lets you download model and model weights.
#
# [https://ai.meta.com/resources/models-and-libraries/llama-downloads/](https://ai.meta.com/resources/models-and-libraries/llama-downloads/)
#
#     - make sure you receive and download url from Meta AI in your email
#         PS> This url is only valid for 24 hours.
#
# These instructions are meant for downloading and running Llama models on Linux machines with GPU.
# *Certain hacks may be required to make it work on Windows and non-GPU machines.*
#
#
# - download Llama git repository
#     `git clone https://github.com/facebookresearch/llama.git`
#
#     PS: > if you don't have Git on your machine,
#
#     `sudo apt install git-all`
#
# - make sure you have `wget` & `md5sum` installed
#
# - browse to llama git repo and run
#     `./download.sh`
#
#     PS: > you may to grant download.sh executable permission
#
#     `chmod +x download.sh`
#
#     enter url
#
#     Hit Enter to download all model and model weight
#
# - browse to your root of llama repository and run
#
#     `pip install -e .`
#
#     This will install all required python packages and dependencies
#
#
# - make appropriate changes to dialogues/prompts in these two files
#
# - test model for prompts
#
#     `torchrun --nproc_per_node 1 example_text_completion.py --ckpt_dir llama-2-7b/ --tokenizer_path tokenizer.model --max_seq_len 128 --max_batch_size 4`
#
#     `torchrun --nproc_per_node 1 example_chat_completion.py --ckpt_dir llama-2-7b/ --tokenizer_path tokenizer.model --max_seq_len 128 --max_batch_size 4`
